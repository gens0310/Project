# %% [markdown]
# # 1. 메모리 변수 제거

# %%
# 메모리 변수 모두 제거
all = [var for var in globals() if var[0] != '_']
for var in all:
    del globals()[var]

# %% [markdown]
# # 2. 사용 패키지

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.7.0
# 2.7.0

# %% [markdown]
# # 3. 데이터 로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Data/데이터셋/kfood/H5
# Out:
# /content/drive/.shortcut-targets-by-id/12Bkw3KJSWQrW556KyI_M_ZzvvQ-HmN21/데이터셋/kfood/H5

# %%
from keras.models import load_model
PATH = '/content/drive/MyDrive/Data/데이터셋/kfood/H5'
model = load_model(PATH + '/' + '통합_CNN_SAMPLE2.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 64, 64, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 64, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 28)                7196
#
# =================================================================
# Total params: 2,394,428
# Trainable params: 2,393,020
# Non-trainable params: 1,408
# _________________________________________________________________

# %% [markdown]
# # 4. 예측
# - 갈비구이 : 0
# - 갈비찜 : 1
# - 갈치조림 : 2
# - 계란말이 : 3
# - 고등어구이 : 4
# - 김밥 : 5
# - 김치찌개 : 6
# - 닭갈비 : 7
# - 닭볶음탕 : 8
# - 떡볶이 : 9
# - 라면 : 10
# - 만두 : 11
# - 미역국 : 12
# - 배추김치 : 13
# - 보쌈 : 14
# - 불고기 : 15
# - 비빔밥 : 16
# - 삼겹살 : 17
# - 삼계탕 : 18
# - 양념치킨 : 19
# - 육개장 : 20
# - 잡채 : 21
# - 제육볶음 : 22
# - 족발 : 23
# - 짜장면 : 24
# - 짬뽕 : 25
# - 파전 : 26
# - 후라이드치킨 : 27

# %%
from google.colab import files
X = []
while True:
    key = str(input('음식 이미지 업로드를 하시겠습니까? (Y/N) : '))
    if key == 'Y':
        print('이미지 파일을 업로드 해주세요.')
        uploaded = files.upload()
        filename = list(uploaded.keys())[0]
        img = Image.open(filename)
        img = img.convert('RGB')
        img = img.resize((64, 64))
        imgarr = np.array(img) / 255
        X.append(imgarr)
    elif key == 'N':
        print('이미지 업로드를 종료합니다.')
        break
    else:
        print('잘못된 값을 입력하셨습니다.')
X = np.array(X, dtype = 'float32')
print(X.shape)
print(type(X))
pred = model.predict(X)
print('----- X -----')
plt.imshow(np.hstack(X))
plt.show()
class_names = ['갈비구이', '갈비찜', '갈치조림', '계란말이', '고등어구이',
               '김밥', '김치찌개', '닭갈비', '닭볶음탕', '떡볶이',
               '라면', '만두', '미역국', '배추김치', '보쌈',
               '불고기', '비빔밥', '삼겹살', '삼계탕', '양념치킨',
               '육개장', '잡채', '제육볶음', '족발', '짜장면',
               '짬뽕', '파전', '후라이드치킨']
print('----- PREDICT -----')
for i in pred:
    print(np.argmax(i), class_names[np.argmax(i)])
# Out:
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-a200b025-6386-4e1c-ac71-942f95c18c32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a200b025-6386-4e1c-ac71-942f95c18c32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 갈비구이.jpg to 갈비구이.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-6474418d-3197-426a-a119-3da6c98953e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6474418d-3197-426a-a119-3da6c98953e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 갈비찜.jpeg to 갈비찜.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-0b4fa863-9a45-49ca-a254-e58a0590bdaf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b4fa863-9a45-49ca-a254-e58a0590bdaf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 갈치조림.jpeg to 갈치조림.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-42b7866a-0e1b-4612-90a8-6cc624a384b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42b7866a-0e1b-4612-90a8-6cc624a384b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 계란말이.jpeg to 계란말이.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-a8c5ef1b-4238-49be-a27d-9e74dc9a61b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8c5ef1b-4238-49be-a27d-9e74dc9a61b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 고등어구이.jpeg to 고등어구이.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-bb491203-3f00-46c1-bd97-8560ea448cd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb491203-3f00-46c1-bd97-8560ea448cd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 김밥.jpeg to 김밥.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-2af3daeb-a8e8-4c2f-acb0-7d31d3bdc1e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2af3daeb-a8e8-4c2f-acb0-7d31d3bdc1e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 김치찌개.jpg to 김치찌개.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-5eb5f01c-7947-401d-bb19-78bf70c388f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5eb5f01c-7947-401d-bb19-78bf70c388f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 닭갈비.jpeg to 닭갈비.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-88530af0-4d58-4d03-aac0-964547c54a38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88530af0-4d58-4d03-aac0-964547c54a38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 닭볶음탕.jpg to 닭볶음탕.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-36b50fd9-e108-4b20-9825-7abb11634c15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36b50fd9-e108-4b20-9825-7abb11634c15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 떡볶이.jpg to 떡볶이.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-e3d81649-c98f-421d-83cd-41744ca6752a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3d81649-c98f-421d-83cd-41744ca6752a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 라면.jpg to 라면.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-1ed90c97-8712-4c6b-809a-38953f554727" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ed90c97-8712-4c6b-809a-38953f554727">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 만두.jpg to 만두.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-3267beb0-6805-41b6-b82c-70e57f8b21a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3267beb0-6805-41b6-b82c-70e57f8b21a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 미역국.jpg to 미역국.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-21d6b7ee-29d7-4427-8236-afe3e1265ee0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21d6b7ee-29d7-4427-8236-afe3e1265ee0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 배추김치.jpg to 배추김치.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-700ad9e0-f951-473c-89ab-2ac9b906076f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-700ad9e0-f951-473c-89ab-2ac9b906076f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 보쌈.jpg to 보쌈.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-82ce4bdf-c79c-4845-9b68-2b9e6fa570a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82ce4bdf-c79c-4845-9b68-2b9e6fa570a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 불고기.jpeg to 불고기.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-8a8ce37e-5c31-415e-881d-abbdbbb7aafd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a8ce37e-5c31-415e-881d-abbdbbb7aafd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 비빔밥.jpg to 비빔밥.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-05c012cf-7cb8-41bd-a7a1-b50f528cc347" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05c012cf-7cb8-41bd-a7a1-b50f528cc347">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 삼겹살.jpg to 삼겹살.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-39492210-c422-470d-910c-0b048d5ff61c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39492210-c422-470d-910c-0b048d5ff61c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 삼계탕.jpeg to 삼계탕.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-c34174d3-0b6d-443d-b72e-1a0dc8663da0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c34174d3-0b6d-443d-b72e-1a0dc8663da0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 양념치킨.jpg to 양념치킨.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-25900b1a-e216-4280-ac33-a774b761abcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25900b1a-e216-4280-ac33-a774b761abcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 육개장.jpg to 육개장.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-43ea3ea7-c1b5-4816-9aaa-b6ef52c8e31f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43ea3ea7-c1b5-4816-9aaa-b6ef52c8e31f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 잡채.jpg to 잡채.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-9d4882cd-966e-4d61-a2ab-edf11f0bea37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d4882cd-966e-4d61-a2ab-edf11f0bea37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 제육볶음.jpeg to 제육볶음.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-b8232fc8-4225-4f1b-aaaf-bf08f94b7215" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8232fc8-4225-4f1b-aaaf-bf08f94b7215">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 족발.jpeg to 족발.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-8b90325a-abe5-4604-9f2c-c320d53a1ade" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b90325a-abe5-4604-9f2c-c320d53a1ade">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 짜장면.jpg to 짜장면.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-ee8302b6-cc07-461f-8353-f90cccc35309" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee8302b6-cc07-461f-8353-f90cccc35309">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 짬뽕.jpeg to 짬뽕.jpeg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-c903514d-4acd-4227-bb99-694383d3592e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c903514d-4acd-4227-bb99-694383d3592e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 파전.jpg to 파전.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : Y
# 이미지 파일을 업로드 해주세요.
#      <input type="file" id="files-c064d2f0-f5ae-4a8f-9d55-05edf6fa21d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c064d2f0-f5ae-4a8f-9d55-05edf6fa21d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 후라이드치킨.jpg to 후라이드치킨.jpg
# 음식 이미지 업로드를 하시겠습니까? (Y/N) : N
# 이미지 업로드를 종료합니다.
# (28, 64, 64, 3)
# <class 'numpy.ndarray'>
# ----- X -----
# ----- PREDICT -----
# 7 닭갈비
# 1 갈비찜
# 13 배추김치
# 3 계란말이
# 4 고등어구이
# 5 김밥
# 6 김치찌개
# 7 닭갈비
# 9 떡볶이
# 9 떡볶이
# 10 라면
# 5 김밥
# 12 미역국
# 13 배추김치
# 14 보쌈
# 21 잡채
# 16 비빔밥
# 17 삼겹살
# 18 삼계탕
# 19 양념치킨
# 20 육개장
# 21 잡채
# 22 제육볶음
# 23 족발
# 24 짜장면
# 25 짬뽕
# 26 파전
# 27 후라이드치킨
